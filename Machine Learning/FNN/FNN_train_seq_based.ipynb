# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Conv1D, GlobalMaxPooling1D, Dense, Concatenate, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle
import matplotlib.pyplot as plt
import time

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv('../datasets/train_set.csv')

# Drop any columns that are not relevant for classification
df = df.drop(columns=['Assembly Code', 'Assembly Description', 'Type Comments'])

EMPTYCONST = "*empty*"

# Define input sequences (example: Family, SubFamily, ObjectGroup)
sequences = ['Family', 'SubFamily', 'Description', 'ObjectGroup', 'ObjectName', 'Type Name', 'Structural Material', 'Material']

# Tokenize and pad each sequence separately
max_words = 200  # Maximum number of words to consider in tokenizer
max_len = 50  # Maximum length of sequences
tokenizer = Tokenizer(num_words=max_words)

X_seqs = []
for seq in sequences:
    X_seq = df[seq].fillna(EMPTYCONST).apply(lambda x: x + "_*" + seq.lower() + "*" if x != EMPTYCONST else x)
    tokenizer.fit_on_texts(X_seq)
    X_seq = tokenizer.texts_to_sequences(X_seq)
    X_seq = pad_sequences(X_seq, maxlen=max_len)
    X_seqs.append(X_seq)

# Split data into features (X) and target variable (y)
y = df["Category"]
y_encoder = LabelEncoder()
y = y_encoder.fit_transform(y)

# Split the dataset into training and testing sets
X_train_seqs = [X_seq[:int(len(X_seq)*0.9)] for X_seq in X_seqs]
X_test_seqs = [X_seq[int(len(X_seq)*0.9):] for X_seq in X_seqs]
y_train = y[:int(len(y)*0.9)]
y_test = y[int(len(y)*0.9):]

# %%
# Start timing
start_time = time.time()
# Define the CNN model using Functional API
input_layers = []
embedding_layers = []
for seq_index, seq in enumerate(sequences):
    input_layer = Input(shape=(max_len,), name=f"input_{seq}")
    embedding_layer = Embedding(input_dim=max_words, output_dim=10, input_length=max_len)(input_layer)
    conv_layer = Conv1D(128, 5, activation='relu')(embedding_layer)
    pool_layer = GlobalMaxPooling1D()(conv_layer)
    input_layers.append(input_layer)
    embedding_layers.append(pool_layer)

merged = Concatenate()(embedding_layers)
dense_layer = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(merged)
dropout_layer = Dropout(0.5)(dense_layer)
output_layer = Dense(len(df['Category'].unique()), activation='softmax')(dropout_layer)

model = Model(inputs=input_layers, outputs=output_layer)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_seqs, y_train, epochs=50, batch_size=32, validation_split=0.1)

# End timing
end_time = time.time()
# Calculate total runtime
total_time = end_time - start_time
print(f"Total runtime: {total_time} seconds")
# Evaluate the model on the testing set
loss, accuracy = model.evaluate(X_test_seqs, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/50
# 77/77 [==============================] - 10s 23ms/step - loss: 2.2332 - accuracy: 0.4765 - val_loss: 3.3655 - val_accuracy: 0.2637
# Epoch 2/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.8936 - accuracy: 0.8221 - val_loss: 2.9555 - val_accuracy: 0.3333
# Epoch 3/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.6150 - accuracy: 0.8719 - val_loss: 2.5861 - val_accuracy: 0.3883
# Epoch 4/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4891 - accuracy: 0.8996 - val_loss: 2.3936 - val_accuracy: 0.4139
# Epoch 5/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4083 - accuracy: 0.9147 - val_loss: 2.3582 - val_accuracy: 0.4945
# Epoch 6/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3536 - accuracy: 0.9245 - val_loss: 2.2140 - val_accuracy: 0.4982
# Epoch 7/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3141 - accuracy: 0.9319 - val_loss: 2.1668 - val_accuracy: 0.5421
# Epoch 8/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2741 - accuracy: 0.9421 - val_loss: 2.1339 - val_accuracy: 0.5421
# Epoch 9/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2492 - accuracy: 0.9498 - val_loss: 2.1211 - val_accuracy: 0.6117
# Epoch 10/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2239 - accuracy: 0.9563 - val_loss: 2.2856 - val_accuracy: 0.5751
# Epoch 11/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2135 - accuracy: 0.9563 - val_loss: 2.2960 - val_accuracy: 0.5971
# Epoch 12/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1974 - accuracy: 0.9592 - val_loss: 2.0986 - val_accuracy: 0.6190
# Epoch 13/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1813 - accuracy: 0.9661 - val_loss: 2.2864 - val_accuracy: 0.5934
# Epoch 14/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1684 - accuracy: 0.9674 - val_loss: 2.2260 - val_accuracy: 0.6154
# Epoch 15/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1653 - accuracy: 0.9661 - val_loss: 2.3629 - val_accuracy: 0.6447
# Epoch 16/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1539 - accuracy: 0.9694 - val_loss: 2.1495 - val_accuracy: 0.6630
# Epoch 17/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1503 - accuracy: 0.9686 - val_loss: 2.3561 - val_accuracy: 0.6593
# Epoch 18/50
# 77/77 [==============================] - 2s 20ms/step - loss: 0.1404 - accuracy: 0.9751 - val_loss: 2.2231 - val_accuracy: 0.6520
# Epoch 19/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1292 - accuracy: 0.9759 - val_loss: 2.3706 - val_accuracy: 0.6520
# Epoch 20/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1310 - accuracy: 0.9755 - val_loss: 2.2194 - val_accuracy: 0.6667
# Epoch 21/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1265 - accuracy: 0.9747 - val_loss: 2.3116 - val_accuracy: 0.6593
# Epoch 22/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1198 - accuracy: 0.9767 - val_loss: 2.3147 - val_accuracy: 0.6667
# Epoch 23/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1155 - accuracy: 0.9755 - val_loss: 2.3502 - val_accuracy: 0.6703
# Epoch 24/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.1046 - accuracy: 0.9800 - val_loss: 2.2747 - val_accuracy: 0.6703
# Epoch 25/50
# 77/77 [==============================] - 2s 20ms/step - loss: 0.1136 - accuracy: 0.9788 - val_loss: 2.3217 - val_accuracy: 0.6557
# Epoch 26/50
# 77/77 [==============================] - 2s 20ms/step - loss: 0.1074 - accuracy: 0.9800 - val_loss: 2.3884 - val_accuracy: 0.6520
# Epoch 27/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1042 - accuracy: 0.9804 - val_loss: 2.3324 - val_accuracy: 0.6630
# Epoch 28/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.1002 - accuracy: 0.9829 - val_loss: 2.4523 - val_accuracy: 0.6447
# Epoch 29/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0889 - accuracy: 0.9841 - val_loss: 2.4802 - val_accuracy: 0.6190
# Epoch 30/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0912 - accuracy: 0.9841 - val_loss: 2.9048 - val_accuracy: 0.6447
# Epoch 31/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0974 - accuracy: 0.9841 - val_loss: 2.5472 - val_accuracy: 0.6264
# Epoch 32/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0872 - accuracy: 0.9837 - val_loss: 2.7757 - val_accuracy: 0.6447
# Epoch 33/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0878 - accuracy: 0.9861 - val_loss: 2.6767 - val_accuracy: 0.6630
# Epoch 34/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0877 - accuracy: 0.9833 - val_loss: 2.6689 - val_accuracy: 0.6410
# Epoch 35/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0826 - accuracy: 0.9865 - val_loss: 2.4620 - val_accuracy: 0.6740
# Epoch 36/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0846 - accuracy: 0.9853 - val_loss: 2.6600 - val_accuracy: 0.6374
# Epoch 37/50
# 77/77 [==============================] - 1s 17ms/step - loss: 0.0825 - accuracy: 0.9841 - val_loss: 2.6026 - val_accuracy: 0.6777
# Epoch 38/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0774 - accuracy: 0.9865 - val_loss: 2.5132 - val_accuracy: 0.6630
# Epoch 39/50
# 77/77 [==============================] - 2s 23ms/step - loss: 0.0750 - accuracy: 0.9890 - val_loss: 2.7154 - val_accuracy: 0.6593
# Epoch 40/50
# 77/77 [==============================] - 2s 21ms/step - loss: 0.0764 - accuracy: 0.9882 - val_loss: 2.6067 - val_accuracy: 0.6593
# Epoch 41/50
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0769 - accuracy: 0.9874 - val_loss: 2.6762 - val_accuracy: 0.6813
# Epoch 42/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0694 - accuracy: 0.9902 - val_loss: 2.7140 - val_accuracy: 0.6777
# Epoch 43/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0759 - accuracy: 0.9849 - val_loss: 2.5529 - val_accuracy: 0.6923
# Epoch 44/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0725 - accuracy: 0.9865 - val_loss: 2.5460 - val_accuracy: 0.6740
# Epoch 45/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0615 - accuracy: 0.9910 - val_loss: 2.8417 - val_accuracy: 0.6703
# Epoch 46/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0612 - accuracy: 0.9890 - val_loss: 2.6992 - val_accuracy: 0.6740
# Epoch 47/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0599 - accuracy: 0.9910 - val_loss: 2.7749 - val_accuracy: 0.6850
# Epoch 48/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0558 - accuracy: 0.9918 - val_loss: 2.9103 - val_accuracy: 0.6850
# Epoch 49/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0591 - accuracy: 0.9906 - val_loss: 2.6269 - val_accuracy: 0.7106
# Epoch 50/50
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0588 - accuracy: 0.9890 - val_loss: 2.7468 - val_accuracy: 0.6886
# Total runtime: 80.46228861808777 seconds
# 10/10 [==============================] - 0s 9ms/step - loss: 5.9682 - accuracy: 0.5182
# Test Accuracy: 0.5181518197059631

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Plot training & validation accuracy values
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.plot(history.history['accuracy'])
#       4 plt.plot(history.history['val_accuracy'])
#       5 plt.title('Model accuracy')
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\pyplot.py:3708, in plot(scalex, scaley, data, *args, **kwargs)
#    3700 @_copy_docstring_and_deprecators(Axes.plot)
#    3701 def plot(
#    3702     *args: float | ArrayLike | str,
#    (...)
#    3706     **kwargs,
#    3707 ) -> list[Line2D]:
# -> 3708     return gca().plot(
#    3709         *args,
#    3710         scalex=scalex,
#    3711         scaley=scaley,
#    3712         **({"data": data} if data is not None else {}),
#    3713         **kwargs,
#    3714     )
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\pyplot.py:2656, in gca()
#    2654 @_copy_docstring_and_deprecators(Figure.gca)
#    2655 def gca() -> Axes:
# -> 2656     return gcf().gca()
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\figure.py:1653, in FigureBase.gca(self)
#    1643 """
#    1644 Get the current Axes.
#    1645
#    (...)
#    1650 whether `.pyplot.get_fignums()` is empty.)
#    1651 """
#    1652 ax = self._axstack.current()
# -> 1653 return ax if ax is not None else self.add_subplot()
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
#     708         args = tuple(map(int, str(args[0])))
#     709     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 710     ax = projection_class(self, *args, **pkw)
#     711     key = (projection_class, pkw)
#     712 return self._add_axes_internal(ax, key)
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\axes\_base.py:672, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     669 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     671 # this call may differ for non-sep axes, e.g., polar
# --> 672 self._init_axis()
#     673 if facecolor is None:
#     674     facecolor = mpl.rcParams['axes.facecolor']
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\axes\_base.py:814, in _AxesBase._init_axis(self)
#     812 def _init_axis(self):
#     813     # This is moved out of __init__ because non-separable axes don't use it
# --> 814     self.xaxis = maxis.XAxis(self, clear=False)
#     815     self.spines.bottom.register_axis(self.xaxis)
#     816     self.spines.top.register_axis(self.xaxis)
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\axis.py:2329, in XAxis.__init__(self, *args, **kwargs)
#    2328 def __init__(self, *args, **kwargs):
# -> 2329     super().__init__(*args, **kwargs)
#    2330     self._init()
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\axis.py:661, in Axis.__init__(self, axes, pickradius, clear)
#     657 self.callbacks = cbook.CallbackRegistry(signals=["units"])
#     659 self._autolabelpos = True
# --> 661 self.label = mtext.Text(
#     662     np.nan, np.nan,
#     663     fontsize=mpl.rcParams['axes.labelsize'],
#     664     fontweight=mpl.rcParams['axes.labelweight'],
#     665     color=mpl.rcParams['axes.labelcolor'],
#     666 )
#     667 self._set_artist_props(self.label)
#     668 self.offsetText = mtext.Text(np.nan, np.nan)
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\text.py:139, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     137 self._x, self._y = x, y
#     138 self._text = ''
# --> 139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#     142     fontproperties=fontproperties,
#     143     usetex=usetex,
#     144     parse_math=parse_math,
#     145     wrap=wrap,
#     146     verticalalignment=verticalalignment,
#     147     horizontalalignment=horizontalalignment,
#     148     multialignment=multialignment,
#     149     rotation=rotation,
#     150     transform_rotates_text=transform_rotates_text,
#     151     linespacing=linespacing,
#     152     rotation_mode=rotation_mode,
#     153     antialiased=antialiased
#     154 )
#     155 self.update(kwargs)
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\text.py:175, in Text._reset_visual_defaults(self, text, color, fontproperties, usetex, parse_math, wrap, verticalalignment, horizontalalignment, multialignment, rotation, transform_rotates_text, linespacing, rotation_mode, antialiased)
#     157 def _reset_visual_defaults(
#     158     self,
#     159     text='',
#    (...)
#     172     antialiased=None
#     173 ):
#     174     self.set_text(text)
# --> 175     self.set_color(mpl._val_or_rc(color, "text.color"))
#     176     self.set_fontproperties(fontproperties)
#     177     self.set_usetex(usetex)
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\text.py:993, in Text.set_color(self, color)
#     990 # "auto" is only supported by axisartist, but we can just let it error
#     991 # out at draw time for simplicity.
#     992 if not cbook._str_equal(color, "auto"):
# --> 993     mpl.colors._check_color_like(color=color)
#     994 self._color = color
#     995 self.stale = True
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'colors'
# Error in callback <function _enable_matplotlib_integration.<locals>.configure_once at 0x0000025BD05D4C10> (for post_run_cell), with arguments args (<ExecutionResult object at 25d5b857ca0, execution_count=6 error_before_exec=None error_in_exec=module 'matplotlib' has no attribute 'colors' info=<ExecutionInfo object at 25d5b857790, raw_cell="# Plot training & validation accuracy values
# plt.f.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/v%3A/F-Project/mcr/BIMVet/Machine%20Learning/FNN/FNN_train_seq_based.ipynb#W3sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib_inline\backend_inline.py:222, in _enable_matplotlib_integration.<locals>.configure_once(*args)
#     221 def configure_once(*args):
# --> 222     activate_matplotlib(backend)
#     223     configure_inline_support(ip, backend)
#     224     ip.events.unregister('post_run_cell', configure_once)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:368, in activate_matplotlib(backend)
#     363 # Due to circular imports, pyplot may be only partially initialised
#     364 # when this function runs.
#     365 # So avoid needing matplotlib attribute-lookup to access pyplot.
#     366 from matplotlib import pyplot as plt
# --> 368 plt.switch_backend(backend)
#     370 plt.show._needmain = False
#     371 # We need to detect at runtime whether show() is called by the user.
#     372 # For this, we wrap it into a decorator which adds a 'called' flag.
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\pyplot.py:505, in switch_backend(newbackend)
#     500     globals()[func_name].__signature__ = inspect.signature(
#     501         getattr(backend_mod, func_name))
#     503 # Need to keep a global reference to the backend for compatibility reasons.
#     504 # See https://github.com/matplotlib/matplotlib/issues/6092
# --> 505 matplotlib.backends.backend = newbackend  # type: ignore[attr-defined]
#     507 if not cbook._str_equal(old_backend, newbackend):
#     508     if get_fignums():
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'backends'

# %%
# Save the model to disk
model.save('FNN_model_py_seq_based.h5')
print("Model saved to disk.")

# Save the label_encoder to a file
with open('label_encoder_seq.pkl', 'wb') as le_file:
    pickle.dump(y_encoder, le_file)
print("LabelEncoder saved to disk.")
# Out:
# Model saved to disk.
