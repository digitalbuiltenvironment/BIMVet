# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Dropout
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import load_model
import tensorflow as tf
import joblib
import time

# %%
# df = pd.DataFrame(data)
file_path = "../datasets/train_set2.csv"
df = pd.read_csv(file_path)

EMPTYCONST = "*empty*"

# Concatenate relevant text features
catFamily = df["Family"].fillna(EMPTYCONST)
catSubFamily = df["SubFamily"].fillna(EMPTYCONST)
catObjectGroup = df["ObjectGroup"].fillna(EMPTYCONST)
catObjectName = df["ObjectName"].fillna(EMPTYCONST)
catDescription = df["Description"].fillna(EMPTYCONST)
catTypeComments = df["Type Comments"].fillna(EMPTYCONST)
catStructuralMaterial = df["Structural Material"].fillna(EMPTYCONST)
catMaterial = df["Material"].fillna(EMPTYCONST)


df["Features"] = (
    catFamily
    + "|"
    + catSubFamily
    + "|"
    + catObjectGroup
    + "|"
    + catObjectName
    + "|"
    + catDescription
    + "|"
    + catTypeComments
    + "|"
    + catStructuralMaterial
    + "|"
    + catMaterial
)

# Start timing
start_time = time.time()

# Encode categorical variable 'Category'
label_encoder = LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Split data into features (X) and target variable (y)
X = df["Features"].fillna(EMPTYCONST)
y = df["Category"]

# Vectorize text data using TF-IDF
vectorizer = CountVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# Convert X_tfidf to a dense numpy array
X_tfidf_dense = X_tfidf.toarray()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf_dense, y, test_size=0.2, random_state=42
)

# Define the neural network model
model_nn = Sequential([
    Dense(units=512, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(units=256, activation='relu'),
    Dropout(0.5),
    Dense(units=64, activation='sigmoid'),
    Dense(len(df['Category'].unique()), activation='softmax')
])


# Compile the model
model_nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model_nn.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# End timing
end_time = time.time()

# Calculate total runtime
total_time = end_time - start_time
print(f"Total runtime: {total_time} seconds")

# Evaluate the model on the testing set
loss, accuracy = model_nn.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)


# Save the model to disk
model_nn.save('FNN_model_cv.h5')
print("Model saved to disk.")
# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, predictions))
# Out:
# Epoch 1/50
# 58/58 [==============================] - 2s 15ms/step - loss: 2.7869 - accuracy: 0.3001 - val_loss: 2.0347 - val_accuracy: 0.6377
# Epoch 2/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.2748 - accuracy: 0.7276 - val_loss: 0.7244 - val_accuracy: 0.8156
# Epoch 3/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.5244 - accuracy: 0.8850 - val_loss: 0.2888 - val_accuracy: 0.9436
# Epoch 4/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.2465 - accuracy: 0.9528 - val_loss: 0.1811 - val_accuracy: 0.9588
# Epoch 5/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.1330 - accuracy: 0.9740 - val_loss: 0.1404 - val_accuracy: 0.9588
# Epoch 6/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0686 - accuracy: 0.9864 - val_loss: 0.1313 - val_accuracy: 0.9544
# Epoch 7/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0436 - accuracy: 0.9935 - val_loss: 0.1124 - val_accuracy: 0.9610
# Epoch 8/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0270 - accuracy: 0.9951 - val_loss: 0.1094 - val_accuracy: 0.9610
# Epoch 9/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0193 - accuracy: 0.9973 - val_loss: 0.1163 - val_accuracy: 0.9631
# Epoch 10/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 0.1267 - val_accuracy: 0.9653
# Epoch 11/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0152 - accuracy: 0.9962 - val_loss: 0.1278 - val_accuracy: 0.9588
# Epoch 12/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0093 - accuracy: 0.9989 - val_loss: 0.1463 - val_accuracy: 0.9588
# Epoch 13/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9631
# Epoch 14/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9631
# Epoch 15/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.1272 - val_accuracy: 0.9588
# Epoch 16/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 0.1493 - val_accuracy: 0.9588
# Epoch 17/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.1317 - val_accuracy: 0.9566
# Epoch 18/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9631
# Epoch 19/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9631
# Epoch 20/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9631
# Epoch 21/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9631
# Epoch 22/50
# 58/58 [==============================] - 1s 10ms/step - loss: 9.7354e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9631
# Epoch 23/50
# 58/58 [==============================] - 1s 10ms/step - loss: 6.7592e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9631
# Epoch 24/50
# 58/58 [==============================] - 1s 10ms/step - loss: 5.9548e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9631
# Epoch 25/50
# 58/58 [==============================] - 1s 10ms/step - loss: 5.5434e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9631
# Epoch 26/50
# 58/58 [==============================] - 1s 10ms/step - loss: 4.7813e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9631
# Epoch 27/50
# 58/58 [==============================] - 1s 10ms/step - loss: 4.3948e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9631
# Epoch 28/50
# 58/58 [==============================] - 1s 11ms/step - loss: 3.9471e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9631
# Epoch 29/50
# 58/58 [==============================] - 1s 10ms/step - loss: 3.7970e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9631
# Epoch 30/50
# 58/58 [==============================] - 1s 11ms/step - loss: 3.3586e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9631
# Epoch 31/50
# 58/58 [==============================] - 1s 10ms/step - loss: 3.1342e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9631
# Epoch 32/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.8845e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9631
# Epoch 33/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.7434e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9631
# Epoch 34/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.5386e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9631
# Epoch 35/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.3367e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9631
# Epoch 36/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.2029e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9631
# Epoch 37/50
# 58/58 [==============================] - 1s 10ms/step - loss: 2.0523e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9631
# Epoch 38/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.8871e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9631
# Epoch 39/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.7946e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9631
# Epoch 40/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.6304e-04 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.9631
# Epoch 41/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.5491e-04 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.9631
# Epoch 42/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.4364e-04 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9631
# Epoch 43/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.3770e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9631
# Epoch 44/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.2769e-04 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9631
# Epoch 45/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.1804e-04 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9631
# Epoch 46/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.1209e-04 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9631
# Epoch 47/50
# 58/58 [==============================] - 1s 10ms/step - loss: 1.0865e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9631
# Epoch 48/50
# 58/58 [==============================] - 1s 10ms/step - loss: 9.7576e-05 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9631
# Epoch 49/50
# 58/58 [==============================] - 1s 10ms/step - loss: 9.8147e-05 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9631
# Epoch 50/50
# 58/58 [==============================] - 1s 10ms/step - loss: 8.8564e-05 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9631
# Total runtime: 31.509866952896118 seconds
# 19/19 [==============================] - 0s 3ms/step - loss: 0.1945 - accuracy: 0.9636
# Test Accuracy: 0.9636048674583435
# Model saved to disk.

# %%
model = load_model('FNN_model_cv.h5')
# Load new data (example: assume `new_data.csv` has the same structure as `train_set.csv`)
new_data_file = "../datasets/test_set.csv"
new_df = pd.read_csv(new_data_file)

model.compile(
    optimizer=tf.keras.optimizers.Adam(),  # or any other optimizer you want to use
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

# Concatenate relevant text features
catFamily = new_df["Family"].fillna("*empty*")
catSubFamily = new_df["SubFamily"].fillna("*empty*")
catObjectGroup = new_df["ObjectGroup"].fillna("*empty*")
catObjectName = new_df["ObjectName"].fillna("*empty*")
catDescription = new_df["Description"].fillna("*empty*")
catTypeComments = new_df["Type Comments"].fillna("*empty*")
catStructuralMaterial = new_df["Structural Material"].fillna("*empty*")
catMaterial = new_df["Material"].fillna("*empty*")

new_df["Features"] = (
    catFamily
    + "|"
    + catSubFamily
    + "|"
    + catObjectGroup
    + "|"
    + catObjectName
    + "|"
    + catDescription
    + "|"
    + catTypeComments
    + "|"
    + catStructuralMaterial
    + "|"
    + catMaterial
)

test2343 = label_encoder.transform(new_df['Category'])


# Vectorize text data using the same CountVectorizer instance
X_new_tfidf = vectorizer.transform(new_df["Features"].fillna(EMPTYCONST))
# Convert X_tfidf to a dense numpy array
X_tfidf_new_dense = X_new_tfidf.toarray()

# Predict using the loaded model
predictions_new = model_nn.predict(X_tfidf_new_dense)
predicted_classes = predictions_new.argmax(axis=1)  # Assuming predictions_new is one-hot encoded

# Calculate accuracy
accuracy = accuracy_score(test2343, predicted_classes)
print("Accuracy:", accuracy)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# Accuracy: 0.7131147540983607
