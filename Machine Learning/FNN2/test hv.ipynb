# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Dropout
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import load_model
import tensorflow as tf
import joblib
import time

# %%
# df = pd.DataFrame(data)
file_path = "../datasets/train_set2.csv"
df = pd.read_csv(file_path)

EMPTYCONST = "*empty*"

# Concatenate relevant text features
catFamily = df["Family"].fillna(EMPTYCONST)
catSubFamily = df["SubFamily"].fillna(EMPTYCONST)
catObjectGroup = df["ObjectGroup"].fillna(EMPTYCONST)
catObjectName = df["ObjectName"].fillna(EMPTYCONST)
catDescription = df["Description"].fillna(EMPTYCONST)
catTypeComments = df["Type Comments"].fillna(EMPTYCONST)
catStructuralMaterial = df["Structural Material"].fillna(EMPTYCONST)
catMaterial = df["Material"].fillna(EMPTYCONST)


df["Features"] = (
    catFamily
    + "|"
    + catSubFamily
    + "|"
    + catObjectGroup
    + "|"
    + catObjectName
    + "|"
    + catDescription
    + "|"
    + catTypeComments
    + "|"
    + catStructuralMaterial
    + "|"
    + catMaterial
)

# Start timing
start_time = time.time()

# Encode categorical variable 'Category'
label_encoder = LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])

# Split data into features (X) and target variable (y)
X = df["Features"].fillna(EMPTYCONST)
y = df["Category"]

# Vectorize text data using TF-IDF
vectorizer = HashingVectorizer(n_features=10000)
X_tfidf = vectorizer.fit_transform(X)

# Convert X_tfidf to a dense numpy array
X_tfidf_dense = X_tfidf.toarray()

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf_dense, y, test_size=0.2, random_state=42
)

# Define the neural network model
model_nn = Sequential([
    Dense(units=512, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(units=256, activation='relu'),
    Dropout(0.5),
    Dense(units=64, activation='sigmoid'),
    Dense(len(df['Category'].unique()), activation='softmax')
])


# Compile the model
model_nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model_nn.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)

# End timing
end_time = time.time()

# Calculate total runtime
total_time = end_time - start_time
print(f"Total runtime: {total_time} seconds")

# Evaluate the model on the testing set
loss, accuracy = model_nn.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)


# Save the model to disk
model_nn.save('FNN_model_hv.h5')
print("Model saved to disk.")
# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, predictions))
# Out:
# Epoch 1/50
# 65/65 [==============================] - 4s 51ms/step - loss: 5.2138 - accuracy: 0.1775 - val_loss: 2.5878 - val_accuracy: 0.2035
# Epoch 2/50
# 65/65 [==============================] - 3s 45ms/step - loss: 2.5431 - accuracy: 0.2118 - val_loss: 2.4621 - val_accuracy: 0.2208
# Epoch 3/50
# 65/65 [==============================] - 3s 48ms/step - loss: 2.5177 - accuracy: 0.2214 - val_loss: 2.4618 - val_accuracy: 0.2208
# Epoch 4/50
# 65/65 [==============================] - 3s 44ms/step - loss: 2.5208 - accuracy: 0.2195 - val_loss: 2.4937 - val_accuracy: 0.2035
# Epoch 5/50
# 65/65 [==============================] - 2s 37ms/step - loss: 2.5276 - accuracy: 0.2262 - val_loss: 2.4409 - val_accuracy: 0.2208
# Epoch 6/50
# 65/65 [==============================] - 3s 45ms/step - loss: 2.5088 - accuracy: 0.2248 - val_loss: 2.4589 - val_accuracy: 0.2208
# Epoch 7/50
# 65/65 [==============================] - 3s 39ms/step - loss: 2.5061 - accuracy: 0.2219 - val_loss: 2.4383 - val_accuracy: 0.2208
# Epoch 8/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5174 - accuracy: 0.2108 - val_loss: 2.4577 - val_accuracy: 0.2035
# Epoch 9/50
# 65/65 [==============================] - 2s 38ms/step - loss: 2.5036 - accuracy: 0.2180 - val_loss: 2.4348 - val_accuracy: 0.2208
# Epoch 10/50
# 65/65 [==============================] - 3s 42ms/step - loss: 2.5103 - accuracy: 0.2214 - val_loss: 2.4534 - val_accuracy: 0.2035
# Epoch 11/50
# 65/65 [==============================] - 3s 44ms/step - loss: 2.5037 - accuracy: 0.2306 - val_loss: 2.4579 - val_accuracy: 0.2208
# Epoch 12/50
# 65/65 [==============================] - 3s 48ms/step - loss: 2.5100 - accuracy: 0.2272 - val_loss: 2.4422 - val_accuracy: 0.2208
# Epoch 13/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5053 - accuracy: 0.2176 - val_loss: 2.4592 - val_accuracy: 0.2035
# Epoch 14/50
# 65/65 [==============================] - 3s 42ms/step - loss: 2.5090 - accuracy: 0.2214 - val_loss: 2.4375 - val_accuracy: 0.2208
# Epoch 15/50
# 65/65 [==============================] - 3s 45ms/step - loss: 2.5074 - accuracy: 0.2190 - val_loss: 2.4817 - val_accuracy: 0.2208
# Epoch 16/50
# 65/65 [==============================] - 3s 52ms/step - loss: 2.5803 - accuracy: 0.2205 - val_loss: 2.4968 - val_accuracy: 0.2208
# Epoch 17/50
# 65/65 [==============================] - 4s 57ms/step - loss: 2.5657 - accuracy: 0.2176 - val_loss: 2.4436 - val_accuracy: 0.2208
# Epoch 18/50
# 65/65 [==============================] - 3s 39ms/step - loss: 2.5181 - accuracy: 0.2200 - val_loss: 2.4352 - val_accuracy: 0.2208
# Epoch 19/50
# 65/65 [==============================] - 2s 35ms/step - loss: 2.5074 - accuracy: 0.2147 - val_loss: 2.4362 - val_accuracy: 0.2208
# Epoch 20/50
# 65/65 [==============================] - 2s 36ms/step - loss: 2.5032 - accuracy: 0.2282 - val_loss: 2.4375 - val_accuracy: 0.2208
# Epoch 21/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5128 - accuracy: 0.2123 - val_loss: 2.4317 - val_accuracy: 0.2208
# Epoch 22/50
# 65/65 [==============================] - 3s 41ms/step - loss: 2.5098 - accuracy: 0.2229 - val_loss: 2.4455 - val_accuracy: 0.2208
# Epoch 23/50
# 65/65 [==============================] - 3s 39ms/step - loss: 2.5038 - accuracy: 0.2180 - val_loss: 2.4798 - val_accuracy: 0.2208
# Epoch 24/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5368 - accuracy: 0.2180 - val_loss: 2.4288 - val_accuracy: 0.2208
# Epoch 25/50
# 65/65 [==============================] - 3s 39ms/step - loss: 2.5037 - accuracy: 0.2267 - val_loss: 2.4372 - val_accuracy: 0.2208
# Epoch 26/50
# 65/65 [==============================] - 4s 54ms/step - loss: 2.5057 - accuracy: 0.2287 - val_loss: 2.4444 - val_accuracy: 0.2035
# Epoch 27/50
# 65/65 [==============================] - 4s 57ms/step - loss: 2.5158 - accuracy: 0.2127 - val_loss: 2.4351 - val_accuracy: 0.2208
# Epoch 28/50
# 65/65 [==============================] - 3s 43ms/step - loss: 2.5009 - accuracy: 0.2065 - val_loss: 2.4303 - val_accuracy: 0.2035
# Epoch 29/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5037 - accuracy: 0.2205 - val_loss: 2.4322 - val_accuracy: 0.2208
# Epoch 30/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5140 - accuracy: 0.2238 - val_loss: 2.4368 - val_accuracy: 0.2208
# Epoch 31/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5038 - accuracy: 0.2224 - val_loss: 2.4262 - val_accuracy: 0.2208
# Epoch 32/50
# 65/65 [==============================] - 3s 42ms/step - loss: 2.5051 - accuracy: 0.2094 - val_loss: 2.4599 - val_accuracy: 0.2035
# Epoch 33/50
# 65/65 [==============================] - 2s 38ms/step - loss: 2.5055 - accuracy: 0.2233 - val_loss: 2.5078 - val_accuracy: 0.2208
# Epoch 34/50
# 65/65 [==============================] - 2s 38ms/step - loss: 2.5070 - accuracy: 0.2272 - val_loss: 2.4368 - val_accuracy: 0.2035
# Epoch 35/50
# 65/65 [==============================] - 3s 42ms/step - loss: 2.5056 - accuracy: 0.2243 - val_loss: 2.4337 - val_accuracy: 0.2208
# Epoch 36/50
# 65/65 [==============================] - 2s 38ms/step - loss: 2.5159 - accuracy: 0.2224 - val_loss: 2.4405 - val_accuracy: 0.2208
# Epoch 37/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5005 - accuracy: 0.2262 - val_loss: 2.4350 - val_accuracy: 0.2208
# Epoch 38/50
# 65/65 [==============================] - 3s 50ms/step - loss: 2.5861 - accuracy: 0.2108 - val_loss: 2.5539 - val_accuracy: 0.2208
# Epoch 39/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5655 - accuracy: 0.2127 - val_loss: 2.4661 - val_accuracy: 0.2035
# Epoch 40/50
# 65/65 [==============================] - 3s 43ms/step - loss: 2.5170 - accuracy: 0.2171 - val_loss: 2.4519 - val_accuracy: 0.2035
# Epoch 41/50
# 65/65 [==============================] - 3s 45ms/step - loss: 2.5188 - accuracy: 0.2311 - val_loss: 2.5042 - val_accuracy: 0.2208
# Epoch 42/50
# 65/65 [==============================] - 3s 40ms/step - loss: 2.5194 - accuracy: 0.2224 - val_loss: 2.4523 - val_accuracy: 0.2208
# Epoch 43/50
# 65/65 [==============================] - 2s 37ms/step - loss: 2.5109 - accuracy: 0.2065 - val_loss: 2.4480 - val_accuracy: 0.2035
# Epoch 44/50
# 65/65 [==============================] - 3s 46ms/step - loss: 2.5098 - accuracy: 0.2253 - val_loss: 2.4719 - val_accuracy: 0.2208
# Epoch 45/50
# 65/65 [==============================] - 3s 41ms/step - loss: 2.5147 - accuracy: 0.2287 - val_loss: 2.4333 - val_accuracy: 0.2208
# Epoch 46/50
# 65/65 [==============================] - 2s 38ms/step - loss: 2.5044 - accuracy: 0.2282 - val_loss: 2.4317 - val_accuracy: 0.2208
# Epoch 47/50
# 65/65 [==============================] - 5s 75ms/step - loss: 2.5012 - accuracy: 0.2219 - val_loss: 2.4356 - val_accuracy: 0.2208
# Epoch 48/50
# 65/65 [==============================] - 5s 74ms/step - loss: 2.5033 - accuracy: 0.2238 - val_loss: 2.4440 - val_accuracy: 0.2208
# Epoch 49/50
# 65/65 [==============================] - 6s 96ms/step - loss: 2.5024 - accuracy: 0.2137 - val_loss: 2.4477 - val_accuracy: 0.2208
# Epoch 50/50
# 65/65 [==============================] - 6s 85ms/step - loss: 2.5029 - accuracy: 0.2113 - val_loss: 2.4442 - val_accuracy: 0.2208
# Total runtime: 151.4026837348938 seconds
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4661 - accuracy: 0.2357
# Test Accuracy: 0.23570190370082855
# Model saved to disk.

# %%
model = load_model('FNN_model_hv.h5')
# Load new data (example: assume `new_data.csv` has the same structure as `train_set.csv`)
new_data_file = "../datasets/test_set.csv"
new_df = pd.read_csv(new_data_file)

model.compile(
    optimizer=tf.keras.optimizers.Adam(),  # or any other optimizer you want to use
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

# Concatenate relevant text features
catFamily = new_df["Family"].fillna("*empty*")
catSubFamily = new_df["SubFamily"].fillna("*empty*")
catObjectGroup = new_df["ObjectGroup"].fillna("*empty*")
catObjectName = new_df["ObjectName"].fillna("*empty*")
catDescription = new_df["Description"].fillna("*empty*")
catTypeComments = new_df["Type Comments"].fillna("*empty*")
catStructuralMaterial = new_df["Structural Material"].fillna("*empty*")
catMaterial = new_df["Material"].fillna("*empty*")

new_df["Features"] = (
    catFamily
    + "|"
    + catSubFamily
    + "|"
    + catObjectGroup
    + "|"
    + catObjectName
    + "|"
    + catDescription
    + "|"
    + catTypeComments
    + "|"
    + catStructuralMaterial
    + "|"
    + catMaterial
)

test2343 = label_encoder.transform(new_df['Category'])


# Vectorize text data using the same CountVectorizer instance
X_new_tfidf = vectorizer.transform(new_df["Features"].fillna(EMPTYCONST))
# Convert X_tfidf to a dense numpy array
X_tfidf_new_dense = X_new_tfidf.toarray()

# Predict using the loaded model
predictions_new = model_nn.predict(X_tfidf_new_dense)
predicted_classes = predictions_new.argmax(axis=1)  # Assuming predictions_new is one-hot encoded

# Calculate accuracy
accuracy = accuracy_score(test2343, predicted_classes)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = load_model('FNN_model_hv.h5')
#       2 # Load new data (example: assume `new_data.csv` has the same structure as `train_set.csv`)
#       3 new_data_file = "../datasets/test_set.csv"
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\xiang\miniconda3\envs\tf\lib\site-packages\keras\backend.py:4302, in batch_set_value(tuples)
#    4300 if tf.executing_eagerly() or tf.inside_function():
#    4301     for x, value in tuples:
# -> 4302         x.assign(np.asarray(value, dtype=dtype_numpy(x)))
#    4303 else:
#    4304     with get_graph().as_default():
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
